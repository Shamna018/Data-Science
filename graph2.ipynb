# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,6,8])
y=np.array([3,5,2,8])
plt.plot(x,y,'o-.y')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,6,8])
y=np.array([3,5,2,8])
plt.plot(x,y,'p:g')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,6,8])
y=np.array([3,5,2,8])
plt.plot(x,y,marker='s',mec='r',ms=10)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,6,8])
y=np.array([3,5,2,8])
plt.plot(x,y,marker='h',mfc='g',ms=20)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,6,8])
y=np.array([3,5,2,8])
plt.plot(x,y,marker='o',mec='r',mfc='g',ms=10)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,6,8])
y=np.array([3,5,2,8])
plt.plot(x,y,marker='o',mec='r',mfc='g',linewidth=6,ms=10)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,6,8])
y=np.array([3,5,2,8])
plt.plot(x,y,marker='o',mfc='g',ms=10,linestyle='dotted',color='r')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,6,8])
y=np.array([3,5,2,8])
plt.plot(x,y,marker='o',mec='g',mfc='y',linewidth=3,ms=10)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,6,8])
y=np.array([3,5,2,8])
plt.plot(x,y,marker='o',mec='g',mfc='y',linewidth=3,ms=10)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('graph')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,6,8])
y=np.array([3,5,2,8])
plt.plot(x,y,marker='o',mec='g',mfc='y',linewidth=3,ms=10)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('graph',loc='right')
plt.show()
